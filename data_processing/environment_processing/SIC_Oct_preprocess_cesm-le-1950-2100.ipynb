# %% [markdown]
# # Sea Ice Concentration in Oct Data Processing from CESM2-LE
# - Process data for Southern Ocean SIC in Oct (for phyto)
# - Notebook by Alice DuVivier (NCAR)
# - Note: this notebook needs to load the utils.py file
# - October 2024

# %% [markdown]
# ## October SIC
#
# - start of melt season and phytoplankton growth, what is ice concentration.

# %%
import utils
import xarray as xr
import numpy as np
import dask
from distributed import Client
from ncar_jobqueue import NCARCluster
from glob import glob
import intake
import importlib
import pop_tools
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
# Out:
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %% [markdown]
# ## Spin up DASK cluster

# %%
# Create our NCAR Cluster - which uses PBSCluster under the hood
cluster = NCARCluster(walltime='2:00:00', cores=1, processes=1, memory='100 GB', 
                      resource_spec='select=1:ncpus=1:mem=100GB',interface='ext')

# Spin up 32 workers
cluster.scale(32)

# Assign the cluster to our Client
client = Client(cluster)

# %%
client
# cluster.close()
# Out:
# <Client: 'tcp://128.117.208.173:34361' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Define some functions we'll need to load data

# %%
# define the metrics we can load 
metrics_dict = {
    "SIC": ['aice'],
}

def get_metrics_list():
    return list(metrics_dict.keys())

# %%
# function to return the variables we need to return for all metrics
def get_metric_variable(metric):
    var_names = metrics_dict[metric]
    # handle the case where there is only one variable
    if isinstance(var_names, str):
        return var_names
    # handle the case where there are multiple variables
    else:
        return var_names[:]

# %%
# function to average over top 150m for relevant variables and to keep time bound
def preprocess(ds):
    tb = ds.time_bounds    
    #re-write time bound with saved value
    ds['time_bound'] = tb
    return ds

# %%
# function for loading datasets
def load_datasets(varnames, experiment,lat_min,lat_max):
    ds_list = []
    for varname in varnames:
        subset = catalog.search(component='ice',
                                variable=varname,
                                experiment=experiment,
                                forcing_variant='cmip6',
                               )
        with dask.config.set(**{'array.slicing.split_large_chunks': True}):
            dsets = subset.to_dataset_dict()
        ds = dsets[f'ice.{experiment}.cice.h.cmip6.{varname}'] 
        
        # compute time mean to get correct months
        ds['time']= ds.time_bounds.compute().mean(dim="d2")
        # keep only some variables
        keep_vars=['time_bounds','TLAT','TLON','tarea','time'] + [varname]
        ds = ds.drop([v for v in ds.variables if v not in keep_vars])
        ds_list.append(ds)
        ds = xr.merge(ds_list, compat="override")
        
        # crop data to the latitudes we want, use given lat/lon, not specific indices
        #ds = ds.isel(nlat=slice(0,37)) # Crop to Southern Ocean, ind_start = 0, ind_end = 37
        ds = ds.where(((ds['TLAT'] <= lat_max) & (ds['TLAT'] >= lat_min)), drop=True)
        
    return ds

# %% [markdown]
# ## Select the metric you are interested in

# %%
import utils

# %%
## Print out potential metrics to investigate:
metrics_list = get_metrics_list()
print(metrics_list)
# Out:
# ['SIC']

# %%
## Enter the metric  of interest:
metric = 'SIC'

# %%
## Enter the years you want to keep:
yy_st = "1950"
yy_ed = "2100"

# %%
## Enter the latitudes you want to keep:
lat_min = -80
lat_max = -60

# %% [markdown]
# ## Load CESM2-LE data

# %%
# for the metric supplied, define the list of required variable names
varnames = get_metric_variable(metric) 
varnames
# Out:
# ['aice']

# %% [markdown]
# ### Load the Data Catalog

# %%
catalog = intake.open_esm_datastore(
    '/glade/collections/cmip/catalog/intake-esm-datastore/catalogs/glade-cesm2-le.json'
)

# %% [markdown]
# ### Load historical data

# %%
# %%time
# load historical
ds_hist = load_datasets(varnames,'historical',lat_min,lat_max)
ds_hist
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.stream.forcing_variant.variable'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# CPU times: user 15.2 s, sys: 539 ms, total: 15.7 s
# Wall time: 30.6 s
# <xarray.Dataset>
# Dimensions:      (nj: 36, ni: 320, time: 1980, d2: 2, member_id: 50)
# Coordinates:
#     TLON         (nj, ni) float32 dask.array<chunksize=(36, 320), meta=np.ndarray>
#     TLAT         (nj, ni) float32 dask.array<chunksize=(36, 320), meta=np.ndarray>
#   * time         (time) object 1850-01-16 12:00:00 ... 2014-12-16 12:00:00
# Dimensions without coordinates: nj, ni, d2, member_id
# Data variables:
#     tarea        (nj, ni) float32 dask.array<chunksize=(36, 320), meta=np.ndarray>
#     time_bounds  (time, d2, nj, ni) object dask.array<chunksize=(120, 2, 36, 320), meta=np.ndarray>
#     aice         (member_id, time, nj, ni) float32 dask.array<chunksize=(1, 120, 36, 320), meta=np.ndarray>
# Attributes:
#     model_doi_url:           https://doi.org/10.5065/D67H1H0V
#     intake_esm_varname:      ['aice']
#     history:                 This dataset was created on 2020-02-01 at 05:49\...
#     comment:                 All years have exactly 365 days
#     comment2:                File written on model date 20100201
#     contents:                Diagnostic and Prognostic Variables
#     time_period_freq:        month_1
#     io_flavor:               io_pio
#     comment3:                seconds elapsed into model date:      0
#     conventions:             CF-1.0
#     source:                  Los Alamos Sea Ice Model (CICE) Version 5
#     intake_esm_dataset_key:  ice.historical.cice.h.cmip6.aice

# %%
# check that this data looks reasonable

mem_5_hist = ds_hist.aice.isel(member_id=5)

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 4))

mem_5_hist.isel(time=0).plot(ax=ax1)
ax1.set_title(mem_5_hist.isel(time=0).time.values)

mem_5_hist.isel(time=1200).plot(ax=ax2)
ax2.set_title(mem_5_hist.isel(time=1200).time.values)

fig.suptitle("first and last ice concentration for hist dataset")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Load future data

# %%
# %%time
# load future
ds_ssp = load_datasets(varnames, 'ssp370',lat_min,lat_max)
ds_ssp
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.stream.forcing_variant.variable'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# CPU times: user 6.79 s, sys: 82.6 ms, total: 6.87 s
# Wall time: 8.11 s
# <xarray.Dataset>
# Dimensions:      (nj: 36, ni: 320, time: 1032, d2: 2, member_id: 50)
# Coordinates:
#     TLON         (nj, ni) float32 dask.array<chunksize=(36, 320), meta=np.ndarray>
#     TLAT         (nj, ni) float32 dask.array<chunksize=(36, 320), meta=np.ndarray>
#   * time         (time) object 2015-01-16 12:00:00 ... 2100-12-16 12:00:00
# Dimensions without coordinates: nj, ni, d2, member_id
# Data variables:
#     tarea        (nj, ni) float32 dask.array<chunksize=(36, 320), meta=np.ndarray>
#     time_bounds  (time, d2, nj, ni) object dask.array<chunksize=(120, 2, 36, 320), meta=np.ndarray>
#     aice         (member_id, time, nj, ni) float32 dask.array<chunksize=(1, 120, 36, 320), meta=np.ndarray>
# Attributes:
#     model_doi_url:           https://doi.org/10.5065/D67H1H0V
#     intake_esm_varname:      ['aice']
#     history:                 This dataset was created on 2020-04-29 at 18:54\...
#     comment:                 All years have exactly 365 days
#     comment2:                File written on model date 20950201
#     contents:                Diagnostic and Prognostic Variables
#     time_period_freq:        month_1
#     io_flavor:               io_pio
#     comment3:                seconds elapsed into model date:      0
#     conventions:             CF-1.0
#     source:                  Los Alamos Sea Ice Model (CICE) Version 5
#     intake_esm_dataset_key:  ice.ssp370.cice.h.cmip6.aice

# %%
# check that this data looks reasonable

mem_5_ssp = ds_ssp.aice.isel(member_id=5)

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 4))

mem_5_ssp.isel(time=0).plot(ax=ax1)
ax1.set_title(mem_5_ssp.isel(time=0).time.values)

mem_5_ssp.isel(time=-1).plot(ax=ax2)
ax2.set_title(mem_5_ssp.isel(time=-1).time.values)

fig.suptitle("first and last NPP for future dataset")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Concatenate historical and future datasets and crop to just the times we need

# %%
ds = xr.concat((ds_hist, ds_ssp),dim='time')
ds.time
# Out:
# <xarray.DataArray 'time' (time: 3012)>
# array([cftime.DatetimeNoLeap(1850, 1, 16, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1850, 2, 15, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1850, 3, 16, 12, 0, 0, 0, has_year_zero=True),
#        ...,
#        cftime.DatetimeNoLeap(2100, 10, 16, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2100, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2100, 12, 16, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 1850-01-16 12:00:00 ... 2100-12-16 12:00:00

# %%
#rename dimensions
ds = ds.rename({'nj':'nlat','ni': 'nlon'})

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 3012, nlat: 36, nlon: 320, d2: 2, member_id: 50)
# Coordinates:
#     TLON         (nlat, nlon) float32 320.6 321.7 322.8 ... 317.2 318.3 319.4
#     TLAT         (nlat, nlon) float32 -79.22 -79.22 -79.22 ... -60.52 -60.52
#   * time         (time) object 1850-01-16 12:00:00 ... 2100-12-16 12:00:00
# Dimensions without coordinates: nlat, nlon, d2, member_id
# Data variables:
#     tarea        (time, nlat, nlon) float32 dask.array<chunksize=(1980, 36, 320), meta=np.ndarray>
#     time_bounds  (time, d2, nlat, nlon) object dask.array<chunksize=(120, 2, 36, 320), meta=np.ndarray>
#     aice         (member_id, time, nlat, nlon) float32 dask.array<chunksize=(1, 120, 36, 320), meta=np.ndarray>
# Attributes:
#     model_doi_url:           https://doi.org/10.5065/D67H1H0V
#     intake_esm_varname:      ['aice']
#     history:                 This dataset was created on 2020-02-01 at 05:49\...
#     comment:                 All years have exactly 365 days
#     comment2:                File written on model date 20100201
#     contents:                Diagnostic and Prognostic Variables
#     time_period_freq:        month_1
#     io_flavor:               io_pio
#     comment3:                seconds elapsed into model date:      0
#     conventions:             CF-1.0
#     source:                  Los Alamos Sea Ice Model (CICE) Version 5
#     intake_esm_dataset_key:  ice.historical.cice.h.cmip6.aice

# %%
# keep just years chosen above
ds = ds.sel(time=slice(yy_st, yy_ed))
#ds = ds.isel(time=slice(1200, 3012)) # Cut timeseries to 1950 - 2100: 1812 time steps
ds.time
# Out:
# <xarray.DataArray 'time' (time: 1812)>
# array([cftime.DatetimeNoLeap(1950, 1, 16, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1950, 2, 15, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1950, 3, 16, 12, 0, 0, 0, has_year_zero=True),
#        ...,
#        cftime.DatetimeNoLeap(2100, 10, 16, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2100, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2100, 12, 16, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 1950-01-16 12:00:00 ... 2100-12-16 12:00:00

# %%
# check that this data looks reasonable

mem_5 = ds.aice.isel(member_id=5)

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 4))

mem_5.isel(time=0).plot(ax=ax1)
ax1.set_title(mem_5.isel(time=0).time.values)

mem_5.isel(time=-1).plot(ax=ax2)
ax2.set_title(mem_5.isel(time=-1).time.values)

fig.suptitle("first and last NPP for concattenated dataset")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Get October SIC

# %%
data = ds['aice']

# %%
# Keep May only
data_keep = data.where(data.time.dt.month == 10, drop=True)

# %% [markdown]
# ## Put together into one dataset

# %% [markdown]
# - Netcdf with variable dimension: (member_id x year x nlat x nlon) Include TLAT and TLONG as coordinates

# %%
# load grid data to include in output file
dir_in = '/glade/u/home/duvivier/masks/'
fin = 'ocn_grid_gx1v7.nc'
ds_grid = xr.open_mfdataset(dir_in+fin,decode_times=False)
ds_grid['nlat'] = ds_grid.nlat
ds_grid['nlon'] = ds_grid.nlon

# crop data to the latitudes we want, use given lat/lon, not specific indices
ds_grid = ds_grid.where(((ds_grid['TLAT'] <= lat_max) & (ds_grid['TLAT'] >= lat_min)), drop=True)

# %%
ds_out = xr.Dataset()

ds_out['SIC_OCT'] = data_keep

# change the attributes
ds_out.attrs['author'] = 'Alice DuVivier'
ds_out.attrs['date_processed'] = datetime.now().strftime('%Y-%m-%d')
ds_out.attrs['contents'] = f'May sea ice fraction in the Southern Ocean from 1950 to 2099.'

ds_out
# Out:
# <xarray.Dataset>
# Dimensions:  (nlat: 36, nlon: 320, time: 151, member_id: 50)
# Coordinates:
#     TLON     (nlat, nlon) float32 320.6 321.7 322.8 323.9 ... 317.2 318.3 319.4
#     TLAT     (nlat, nlon) float32 -79.22 -79.22 -79.22 ... -60.52 -60.52 -60.52
#   * time     (time) object 1950-10-16 12:00:00 ... 2100-10-16 12:00:00
# Dimensions without coordinates: nlat, nlon, member_id
# Data variables:
#     SIC_OCT  (member_id, time, nlat, nlon) float32 dask.array<chunksize=(1, 10, 36, 320), meta=np.ndarray>
# Attributes:
#     author:          Alice DuVivier
#     date_processed:  2025-07-30
#     contents:        May sea ice fraction in the Southern Ocean from 1950 to ...

# %%
# Print the dimensions
print("Dimensions:")
for dim in ds_out.dims:
    print(f"\t{dim}: {ds_out[dim].values.shape}")

# Print the coordinates
print("Coordinates:")
for coord in ds_out.coords:
    print(f"\t{coord}:")
    print(f"\t\t{ds_out.coords[coord].values}")
    
# Print the attributes
print("Attributes:")
for attr in ds_out.attrs:
    print(f"\t{attr}: {ds_out.attrs[attr]}")
# Out:
# Dimensions:
# 	nlat: (36,)
# 	nlon: (320,)
# 	time: (151,)
# 	member_id: (50,)
# Coordinates:
# 	TLON:
# 		[[320.5625 321.6875 322.8125 ... 317.1875 318.3125 319.4375]
#  [320.5625 321.6875 322.8125 ... 317.1875 318.3125 319.4375]
#  [320.5625 321.6875 322.8125 ... 317.1875 318.3125 319.4375]
#  ...
#  [320.5625 321.6875 322.8125 ... 317.1875 318.3125 319.4375]
#  [320.5625 321.6875 322.8125 ... 317.1875 318.3125 319.4375]
#  [320.5625 321.6875 322.8125 ... 317.1875 318.3125 319.4375]]
# 	TLAT:
# 		[[-79.22052  -79.22052  -79.22052  ... -79.22052  -79.22052  -79.22052 ]
#  [-78.68631  -78.68631  -78.68631  ... -78.68631  -78.68631  -78.68631 ]
#  [-78.15209  -78.15209  -78.15209  ... -78.15209  -78.15209  -78.15209 ]
#  ...
#  [-61.59125  -61.59125  -61.59125  ... -61.59125  -61.59125  -61.59125 ]
#  [-61.057022 -61.057022 -61.057022 ... -61.057022 -61.057022 -61.057022]
#  [-60.522797 -60.522797 -60.522797 ... -60.522797 -60.522797 -60.522797]]
# 	time:
# 		[cftime.DatetimeNoLeap(1950, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1951, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1952, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1953, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1954, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1955, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1956, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1957, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1958, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1959, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1960, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1961, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1962, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1963, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1964, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1965, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1966, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1967, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1968, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1969, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1970, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1971, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1972, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1973, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1974, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1975, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1976, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1977, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1978, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1979, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1980, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1981, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1982, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1983, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1984, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1985, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1986, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1987, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1988, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1989, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1990, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1991, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1992, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1993, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1994, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1995, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1996, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1997, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1998, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1999, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2000, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2001, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2002, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2003, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2004, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2005, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2006, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2007, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2008, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2009, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2010, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2011, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2012, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2013, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2014, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2015, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2016, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2017, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2018, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2019, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2020, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2021, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2022, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2023, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2024, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2025, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2026, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2027, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2028, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2029, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2030, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2031, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2032, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2033, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2034, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2035, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2036, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2037, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2038, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2039, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2040, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2041, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2042, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2043, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2044, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2045, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2046, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2047, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2048, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2049, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2050, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2051, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2052, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2053, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2054, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2055, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2056, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2057, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2058, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2059, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2060, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2061, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2062, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2063, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2064, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2065, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2066, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2067, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2068, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2069, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2070, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2071, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2072, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2073, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2074, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2075, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2076, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2077, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2078, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2079, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2080, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2081, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2082, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2083, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2084, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2085, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2086, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2087, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2088, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2089, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2090, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2091, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2092, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2093, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2094, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2095, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2096, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2097, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2098, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2099, 10, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(2100, 10, 16, 12, 0, 0, 0, has_year_zero=True)]
# Attributes:
# 	author: Alice DuVivier
# 	date_processed: 2025-07-30
# 	contents: May sea ice fraction in the Southern Ocean from 1950 to 2099.

# %% [markdown]
# ## Export and Save

# %%
# calculate the size of the dataset in GB
size_gb = ds_out.nbytes / (1024**3)
print(f"The dataset is approximately {size_gb:.2f} GB.")
# Out:
# The dataset is approximately 0.32 GB.

# %%
path_out = '/glade/campaign/cgd/ppc/duvivier/cesm2_antarctic_polynya/mpa_analysis/DATA/ecoindex_data/environment/'
file_out = 'CESM2-LE-SIC_OCT.nc'
fout = path_out + file_out

# %%
# Export the dataset to NetCDF with all attributes and coordinates
ds_out.to_netcdf(fout)

# %%
cluster.close()

# %% [markdown]
# ## Test if it worked

# %%
import netCDF4
nc = netCDF4.Dataset(fout)
print(nc.variables)
# Out:
# {'TLON': <class 'netCDF4._netCDF4.Variable'>
# float32 TLON(nlat, nlon)
#     _FillValue: 1e+30
#     long_name: T grid center longitude
#     units: degrees_east
#     bounds: lont_bounds
#     missing_value: 1e+30
# unlimited dimensions:
# current shape = (36, 320)
# filling on, 'TLAT': <class 'netCDF4._netCDF4.Variable'>
# float32 TLAT(nlat, nlon)
#     _FillValue: 1e+30
#     long_name: T grid center latitude
#     units: degrees_north
#     bounds: latt_bounds
#     missing_value: 1e+30
# unlimited dimensions:
# current shape = (36, 320)
# filling on, 'time': <class 'netCDF4._netCDF4.Variable'>
# int64 time(time)
#     units: days since 1950-10-16 12:00:00.000000
#     calendar: noleap
# unlimited dimensions:
# current shape = (151,)
# filling on, default _FillValue of -9223372036854775806 used, 'SIC_OCT': <class 'netCDF4._netCDF4.Variable'>
# float32 SIC_OCT(member_id, time, nlat, nlon)
#     _FillValue: nan
#     units: 1
#     long_name: ice area  (aggregate)
#     cell_measures: area: tarea
#     cell_methods: time: mean
#     time_rep: averaged
#     coordinates: TLAT TLON
# unlimited dimensions:
# current shape = (50, 151, 36, 320)
# filling on}

# %%
path =  path_out
ds_in =  xr.open_dataset(path_out+file_out, decode_times=True)

# %%
ds_in.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	nlat = 36 ;
# 	nlon = 320 ;
# 	time = 151 ;
# 	member_id = 50 ;
#
# variables:
# 	float32 TLON(nlat, nlon) ;
# 		TLON:long_name = T grid center longitude ;
# 		TLON:units = degrees_east ;
# 		TLON:bounds = lont_bounds ;
# 	float32 TLAT(nlat, nlon) ;
# 		TLAT:long_name = T grid center latitude ;
# 		TLAT:units = degrees_north ;
# 		TLAT:bounds = latt_bounds ;
# 	object time(time) ;
# 	float32 SIC_OCT(member_id, time, nlat, nlon) ;
# 		SIC_OCT:units = 1 ;
# 		SIC_OCT:long_name = ice area  (aggregate) ;
# 		SIC_OCT:cell_measures = area: tarea ;
# 		SIC_OCT:cell_methods = time: mean ;
# 		SIC_OCT:time_rep = averaged ;
#
# // global attributes:
# 	:author = Alice DuVivier ;
# 	:date_processed = 2025-07-30 ;
# 	:contents = May sea ice fraction in the Southern Ocean from 1950 to 2099. ;
# }

# %%
mem_5_ints = ds_in.SIC_OCT.isel(member_id=5)

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 4))

mem_5_ints.isel(time=0).plot(ax=ax1)

mem_5_ints.isel(time=-1).plot(ax=ax2)

fig.suptitle("first and last SIZ")

plt.tight_layout()
plt.show()
